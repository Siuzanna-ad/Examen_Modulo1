# %%
#La clase TiendaOnline debe tener los siguientes atributos:

# %%
#1.1 y 1.2
#Crea una clase llamada TiendaOnline que cumpla con los siguientes requisitos:
#Un atributo llamado inventario, que es una lista de diccionarios.
#Cada diccionario representa un producto.
#Cada producto tiene las claves: 'nombre', 'precio', 'cantidad'.
#El inventario comienza vacío.
#Un atributo llamado ventas_totales, de tipo float.
#Lleva el registro de todas las ventas realizadas.
#Inicia en 0.0.
class TiendaOnline:
    def __init__(self):
        # Inventario vacío al inicio
        self.inventario = []

        # Total de ventas, inicia en 0
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
      # Agrega un nuevo producto al inventario.
        #Si el producto ya existe, aumenta su cantidad.
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                producto['cantidad'] += cantidad
                print(f"Producto existente actualizado: {nombre}")
                return

        # Si el producto no existe, lo agrega como nuevo
        nuevo_producto = {
            'nombre': nombre,
            'precio': precio,
            'cantidad': cantidad
        }
        self.inventario.append(nuevo_producto)
        print(f"Producto agregado: {nombre}")

    def vender_producto(self, nombre, cantidad):
        #Vende un producto si hay suficiente en inventario.
        #Actualiza las ventas totales.
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                if producto['cantidad'] >= cantidad:
                    producto['cantidad'] -= cantidad
                    total_venta = producto['precio'] * cantidad
                    self.ventas_totales += total_venta
                    print(f"Venta realizada: {nombre} x{cantidad}")
                    return
                else:
                    print("No hay suficiente cantidad en inventario.")
                    return

        print("Producto no encontrado en el inventario.")

    def mostrar_inventario(self):
        #Muestra todos los productos disponibles en el inventario.
    
        if not self.inventario:
            print("El inventario está vacío.")
        else:
            print("Inventario actual:")
            for producto in self.inventario:
                print(f"- {producto['nombre']}: ${producto['precio']} ({producto['cantidad']} disponibles)")

    def mostrar_ventas_totales(self):
        #Muestra el total acumulado de ventas.
        
        print(f"Ventas totales: ${self.ventas_totales:.2f}")

# %%
#EJEMPLO:
# Crear tienda
tienda = TiendaOnline()

# Agregar productos
tienda.agregar_producto("Camisa", 20, 40)
tienda.agregar_producto("Pantalón", 30, 30)

# Mostrar inventario
tienda.mostrar_inventario()

# Vender productos
tienda.vender_producto("Camisa", 5)
tienda.vender_producto("Pantalón", 2)

# Mostrar inventario después de la venta
tienda.mostrar_inventario()

# Mostrar ventas totales
tienda.mostrar_ventas_totales()
# Out:
# Producto agregado: Camisa
# Producto agregado: Pantalón
# Inventario actual:
# - Camisa: $20 (40 disponibles)
# - Pantalón: $30 (30 disponibles)
# Venta realizada: Camisa x5
# Venta realizada: Pantalón x2
# Inventario actual:
# - Camisa: $20 (35 disponibles)
# - Pantalón: $30 (28 disponibles)
# Ventas totales: $160.00

# %%
#La clase TiendaOnline debe tener los siguientes métodos:

# %%
#2.1
#El método se llama agregar_producto.
#Recibe tres parámetros: nombre, precio y cantidad.
#Recorre el inventario (una lista de diccionarios).
#Si ya existe un producto con el mismo nombre, aumenta su cantidad.
#Si no existe, agrega un nuevo producto como un diccionario al inventario.
class TiendaOnline:
    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
       #Agrega un producto al inventario o actualiza su cantidad si ya existe.

        for producto in self.inventario:
            # Compara los nombres (ignorando mayúsculas/minúsculas)
            if producto['nombre'].lower() == nombre.lower():
                # Si ya existe, actualiza la cantidad
                producto['cantidad'] += cantidad
                print(f"Producto existente actualizado: {nombre}")
                return

        # Si no existe, agrega uno nuevo al inventario
        nuevo_producto = {
            'nombre': nombre,
            'precio': precio,
            'cantidad': cantidad
        }
        self.inventario.append(nuevo_producto)
        print(f"Nuevo producto agregado: {nombre}")

# %%
#EJEMPLO:
tienda = TiendaOnline()

# Agregamos productos
tienda.agregar_producto("Camisa", 20, 10)
tienda.agregar_producto("Camisa", 20, 5)   # Este actualiza cantidad, no crea uno nuevo
tienda.agregar_producto("Pantalón", 30, 7)

# Verificamos el inventario
for producto in tienda.inventario:
    print(producto)
# Out:
# Nuevo producto agregado: Camisa
# Producto existente actualizado: Camisa
# Nuevo producto agregado: Pantalón
# {'nombre': 'Camisa', 'precio': 20, 'cantidad': 15}
# {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 7}

# %%
#2.2
class TiendaOnline:
    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                producto['cantidad'] += cantidad
                return
        nuevo_producto = {
            'nombre': nombre,
            'precio': precio,
            'cantidad': cantidad
        }
        self.inventario.append(nuevo_producto)

    def ver_inventario(self):
        #Muestra todos los productos del inventario con nombre, precio y cantidad.
        if not self.inventario:
            print("El inventario está vacío.")
        else:
            for producto in self.inventario:
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")

# %%
#EJEMPLO
tienda = TiendaOnline()

tienda.agregar_producto("Camisa", 20, 50)
tienda.agregar_producto("Pantalón", 30, 30)
tienda.agregar_producto("Zapatos", 50, 40)

# Mostrar inventario
tienda.ver_inventario()
# Out:
# Nombre: Camisa, Precio: $20, Cantidad: 50
# Nombre: Pantalón, Precio: $30, Cantidad: 30
# Nombre: Zapatos, Precio: $50, Cantidad: 40

# %%
#2.3
#Se llama buscar_producto.
#Recibe como parámetro el nombre del producto que se quiere buscar.
#Utiliza un bucle for para recorrer la lista de productos en el inventario.
#Compara el nombre del producto buscado con el nombre de cada producto en el inventario.
#Si lo encuentra, muestra sus detalles: Nombre, Precio, Cantidad.
#Si no lo encuentra, muestra un mensaje indicando que no se encontró.
class TiendaOnline:
    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                producto['cantidad'] += cantidad
                return
        nuevo_producto = {
            'nombre': nombre,
            'precio': precio,
            'cantidad': cantidad
        }
        self.inventario.append(nuevo_producto)

    def ver_inventario(self):
        if not self.inventario:
            print("El inventario está vacío.")
        else:
            for producto in self.inventario:
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")

    def buscar_producto(self, nombre):
        #Busca un producto por su nombre e imprime sus detalles si se encuentra.
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")
                return
        print(f"Producto '{nombre}' no encontrado en el inventario.")

# %%
#EJEMPLO
tienda = TiendaOnline()

# Agregamos productos
tienda.agregar_producto("Camisa", 20, 40)
tienda.agregar_producto("Zapatos", 50, 20)

# Buscamos un producto
tienda.buscar_producto("Camisa")   # Producto que sí existe
tienda.buscar_producto("Pantalón") # Producto que no existe
# Out:
# Nombre: Camisa, Precio: $20, Cantidad: 40
# Producto 'Pantalón' no encontrado en el inventario.

# %%
#2.4
class TiendaOnline:
    def __init__(self):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                producto['cantidad'] += cantidad
                return
        nuevo_producto = {
            'nombre': nombre,
            'precio': precio,
            'cantidad': cantidad
        }
        self.inventario.append(nuevo_producto)

    def ver_inventario(self):
        if not self.inventario:
            print("El inventario está vacío.")
        else:
            for producto in self.inventario:
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")

    def buscar_producto(self, nombre):
       #Busca un producto por su nombre e imprime sus detalles si se encuentra.

        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower():
                print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")
                return
        print(f"Producto '{nombre}' no encontrado en el inventario.")

# %%
#EJEMPLO:
tienda = TiendaOnline()
tienda.agregar_producto("Manzana", 0.50, 100)
tienda.buscar_producto("manzana")
# Out:
# Nombre: Manzana, Precio: $0.5, Cantidad: 100

# %%
#2.5
def eliminar_producto(self, nombre):
    for i, producto in enumerate(self.inventario):
        if producto['nombre'].lower() == nombre.lower():
            del self.inventario[i]
            print(f"Producto '{nombre}' eliminado del inventario.")
            return
    print(f"Producto '{nombre}' no encontrado en el inventario.")

# %%
#EJEMPLO
class Tienda:
    def __init__(self):
        self.inventario = [
            {'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},
            {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30}
        ]

    def eliminar_producto(self, nombre):
        for i, producto in enumerate(self.inventario):
            if producto['nombre'].lower() == nombre.lower():
                del self.inventario[i]
                print(f"Producto '{nombre}' eliminado del inventario.")
                return
        print(f"Producto '{nombre}' no encontrado en el inventario.")

# Uso
tienda = Tienda()
tienda.eliminar_producto("Camisa")     # Producto 'Camisa' eliminado del inventario.
tienda.eliminar_producto("Zapatos")    # Producto 'Zapatos' no encontrado en el inventario.
# Out:
# Producto 'Camisa' eliminado del inventario.
# Producto 'Zapatos' no encontrado en el inventario.

# %%
#2.6
#Usar un bucle for para recorrer el inventario.
#Multiplicar precio × cantidad de cada producto.
#Sumar todos esos valores y mostrar el valor total del inventario.
def calcular_valor_inventario(self):
    #Calcula y muestra el valor total del inventario (precio × cantidad por producto).

        valor_total = 0
        for producto in self.inventario:
            valor_producto = producto['precio'] * producto['cantidad']
            valor_total += valor_producto
        print(f"Valor total del inventario: {valor_total} euros")

# %%
#EJEMPLO
class Tienda:
    def __init__(self):
        self.inventario = [
            {'nombre': 'Camisa', 'precio': 5, 'cantidad': 5},
            {'nombre': 'Calcetín', 'precio': 1, 'cantidad': 10}
        ]

    def calcular_valor_inventario(self):
        valor_total = 0
        for producto in self.inventario:
            valor_producto = producto['precio'] * producto['cantidad']
            valor_total += valor_producto
        print(f"Valor total del inventario: {valor_total} euros")

# Crear la tienda y llamar al método:
mi_tienda = Tienda()
mi_tienda.calcular_valor_inventario()
# Out:
# Valor total del inventario: 35 euros
